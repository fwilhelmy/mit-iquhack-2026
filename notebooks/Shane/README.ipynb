# %% [markdown]
# # iQuHack 2026 - Quantum Entanglement Distillation Game
#
# A competitive quantum networking game where players build subgraphs by claiming edges through entanglement distillation.
#
# ## Quick Start
# ### 1. Install Dependencies

# %%
#python3 -m venv venv
#source venv/bin/activate
# %pip install -r requirements.txt
# Out:
# Collecting qiskit==2.3.0 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting networkx==3.4.2 (from -r requirements.txt (line 2))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: requests==2.32.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: ipykernel==7.1.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (7.1.0)
# Collecting matplotlib>=3.7.0 (from -r requirements.txt (line 5))
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting rustworkx>=0.15.0 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting numpy<3,>=1.17 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting scipy>=1.5 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting dill>=0.3 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/py312/lib/python3.12/site-packages (from qiskit==2.3.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests==2.32.5->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests==2.32.5->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests==2.32.5->-r requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests==2.32.5->-r requirements.txt (line 3)) (2026.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (26.0)
# Requirement already satisfied: psutil>=5.7 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipykernel==7.1.0->-r requirements.txt (line 4)) (5.14.3)
# Collecting pydot (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting Pillow>=4.2.1 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pylatexenc>=1.4 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting seaborn>=0.9.0 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting sympy>=1.3 (from qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7.0->-r requirements.txt (line 5))
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7.0->-r requirements.txt (line 5))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7.0->-r requirements.txt (line 5))
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7.0->-r requirements.txt (line 5))
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.7.0->-r requirements.txt (line 5))
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/py312/lib/python3.12/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: decorator>=4.3.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/conda/envs/py312/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/envs/py312/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.17.0)
# Collecting pandas>=1.2 (from seaborn>=0.9.0->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/conda/envs/py312/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.1.0->-r requirements.txt (line 4)) (0.2.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.3->qiskit[visualization]==2.3.0->-r requirements.txt (line 1))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading qiskit-2.3.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 18.7 MB/s  0:00:00 eta 0:00:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.4 MB/s  0:00:00
# Downloading numpy-2.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 15.8 MB/s  0:00:01m0:00:0100:01
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 11.8 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 12.9 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.0 MB/s  0:00:00
# Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 11.3 MB/s  0:00:00 eta 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.7 MB/s  0:00:00 eta 0:00:01
# Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 8.2 MB/s  0:00:04m0:00:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 13.4 MB/s  0:00:00m0:00:010:01
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 13.8 MB/s  0:00:00 eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.1 MB/s  0:00:00
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (pyproject.toml) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136898 sha256=ec74ac4166246598723a16a2eb7c9e5160485281ce9a81e311d3167eddcb258c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, mpmath, sympy, stevedore, pyparsing, Pillow, numpy, networkx, kiwisolver, fonttools, dill, cycler, scipy, rustworkx, pydot, pandas, contourpy, qiskit, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [seaborn]9/20 [seaborn]ib]
# Successfully installed Pillow-12.1.0 contourpy-1.3.3 cycler-0.12.1 dill-0.4.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 mpmath-1.3.0 networkx-3.4.2 numpy-2.4.1 pandas-3.0.0 pydot-4.0.1 pylatexenc-2.10 pyparsing-3.3.2 qiskit-2.3.0 rustworkx-0.17.1 scipy-1.17.0 seaborn-0.13.2 stevedore-5.6.0 sympy-1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Start Playing
#
# Open `demo.ipynb` in Jupyter or VS Code:

# %%
jupyter notebook demo.ipynb
# Out:
#   Cell In[7], line 1
#     jupyter notebook demo.ipynb
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# The notebook walks you through registration, gameplay, and circuit design.

# %% [markdown]
# ## Game Overview
#
# **Objective**: Build a quantum network subgraph to maximize your score.
#
# **How It Works**:
# 1. Register with a unique player ID
# 2. Select a starting node from candidates
# 3. Design distillation circuits to improve noisy Bell pair fidelity
# 4. Claim edges by beating fidelity thresholds
# 5. Earn points from nodes with utility qubits
# 6. Manage your limited bell pair budget
#
# **Key Mechanics**:
# - **Graph**: Quantum network with nodes (utility qubits) and edges (entanglement links)
# - **Distillation**: Submit circuits to purify noisy Bell pairs
# - **Thresholds**: Achieve fidelity >= threshold to claim an edge
# - **Budget**: Limited bell pairs for distillation attempts
# - **Scoring**: Sum of utility qubits from owned nodes
#
# ---
#
# ## Repository Structure
#
# ```
# iQuHack2026/
# ├── demo.ipynb         # Interactive tutorial - START HERE
# ├── client.py          # GameClient class (API wrapper)
# ├── visualization.py   # GraphTool class (graph rendering)
# ├── game_handbook.md   # Detailed game rules
# ├── requirements.txt   # Python dependencies
# └── README.md          # This file
# ```
#
# ---
#
# ## SDK Usage
#
# ### GameClient
#
# ```python
# from client import GameClient
#
# client = GameClient()
# result = client.register("player_id", "Name", location="remote")
#
# # Select starting node
# client.select_starting_node(node_id)
#
# # Get claimable edges
# claimable = client.get_claimable_edges()
#
# # Claim an edge with a circuit
# result = client.claim_edge(edge, circuit, flag_bit, num_bell_pairs)
#
# # Check status
# client.print_status()
# ```
#
# ### GraphTool
#
# ```python
# from visualization import GraphTool
#
# viz = GraphTool(client.get_cached_graph())
# owned = set(status.get('owned_nodes', []))
#
# # Render focused view (nodes within 2 hops)
# viz.render(owned, radius=2)
#
# # Text summary
# viz.print_summary(owned)
# ```
#
# ---
#
# ## API Endpoints
#
# Base URL: `https://demo-entanglement-distillation-qfhvrahfcq-uc.a.run.app`
#
# **Public**:
# - `GET /v1/graph` - Get graph structure
# - `GET /v1/leaderboard` - Get player rankings
#
# **Protected** (Bearer token required):
# - `POST /v1/register` - Register player (returns api_token)
# - `POST /v1/select_starting_node` - Choose starting node
# - `POST /v1/claim_edge` - Submit distillation circuit
# - `GET /v1/status/{player_id}` - Get player status
# - `POST /v1/restart` - Reset progress
#
# ---
#
# ## Strategy Tips
#
# 1. **Starting Node**: Balance utility qubits vs. bonus bell pairs
# 2. **Edge Claiming**: Start with low-difficulty edges
# 3. **Circuit Design**: More bell pairs improve fidelity but cost more budget
# 4. **Budget**: Failed attempts are free - only successful claims cost bell pairs
#
# ---
#
# ## Troubleshooting
#
# **"Module not found"**: Run `pip install -r requirements.txt`
#
# **"Invalid token"**: Re-register or use saved session token
#
# **Visualization not showing**: Install matplotlib: `pip install matplotlib`
#
# ---
#
# ## Support
#
# See `demo.ipynb` for comprehensive examples. For issues, check the game handbook or ask the organizers.
#
# Good luck!
